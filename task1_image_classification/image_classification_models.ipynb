# %% [markdown]
# # Task 1: Train and Benchmark 3 Image Classification Models
#
# ### 🎯 Objective:
# To train and evaluate 3 different image classification models using a real-world dataset. We will:
# - Use **MobileNetV2**, **ResNet50**, and **YOLOv8 Classification**
# - Download and prepare the **Oxford Flowers 102** dataset
# - Train each model
# - Save them in `.keras` or `.onnx` formats
# - Run inference and ensure at least one model achieves **< 20ms per-image inference time on CPU**
# - Quantize models for faster performance on CPU using TensorFlow Lite

# %% [markdown]
# ## 📦 Step 1: Install Dependencies
#
# We need:
# - `tensorflow` for MobileNet and ResNet
# - `ultralytics` for YOLOv8
# - `onnxruntime` for ONNX inference
# - `tensorflow_datasets` to load the Oxford Flowers dataset

# %%
# ✅ STEP 0: SETUP
# !pip install -q tensorflow datasets ultralytics onnxruntime
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 114.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.173-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.173-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.173 ultralytics-thop-2.0.14

# %%
import os
import numpy as np
import time
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)
gpu_devices = tf.config.list_physical_devices('GPU')
print("Using GPU:", gpu_devices)


if not gpu_devices:
    print("No GPU devices found. Training will run on CPU.")
else:
    print(f"Number of GPU devices available: {len(gpu_devices)}")
    try:

        from tensorflow.python.compiler.mlir import mlir_graph_util
        print("CUDA version:", mlir_graph_util._pywrap_get_cuda_version())
    except Exception as e:
        print(f"Could not get CUDA version: {e}")


    if len(gpu_devices) > 0:
        try:
            tf.config.set_visible_devices(gpu_devices[0], 'GPU')
            logical_gpus = tf.config.list_logical_devices('GPU')
            print(f"Logical GPU devices configured: {logical_gpus}")
        except RuntimeError as e:
            print(f"Invalid device or cannot modify logical device configuration: {e}")
# Out:
# TensorFlow version: 2.18.0
# Using GPU: []
# No GPU devices found. Training will run on CPU.

# %% [markdown]
# ## 🌸 Step 2: Download and Prepare Oxford Flowers Dataset
#
# We use `tensorflow_datasets` to load the Oxford Flowers 102 dataset and convert it into a folder structure that resembles:
# dataset/
# ├── train/
# │ ├── classA/
# │ └── classB/
# └── valid/
# ├── classA/
# └── classB/

# %%
# ✅ STEP 1: DOWNLOAD & EXTRACT OXFORD FLOWERS
import tensorflow_datasets as tfds

data, info = tfds.load('oxford_flowers102', with_info=True, as_supervised=True)
train_data, valid_data, test_data = data['train'], data['validation'], data['test']
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_flowers102/2.1.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.174H9X_2.1.1/oxford_flowers102-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.174H9X_2.1.1/oxford_flowers102-test.tfrecord*…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.174H9X_2.1.1/oxford_flowers102-validation.tfr…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.

# %% [markdown]
# ## 🧪 Step 3: Prepare ImageDataGenerators for Training
#
# We rescale pixel values and prepare iterators for the train and validation sets.

# %%
import pathlib
from PIL import Image
import os
import tensorflow as tf

def save_dataset_to_dir(dataset, base_dir):
    for i, (img, label) in enumerate(dataset):
        try:

            cls = str(label.numpy())
            class_dir = os.path.join(base_dir, cls)
            os.makedirs(class_dir, exist_ok=True)


            if img.shape[-1] == 1:
                img = tf.image.grayscale_to_rgb(img)


            img = tf.image.resize_with_pad(img, 224, 224)
            img = tf.clip_by_value(img, 0, 255)
            img = tf.cast(img, tf.uint8).numpy()


            im = Image.fromarray(img)
            im.save(os.path.join(class_dir, f"{i}.jpg"))

        except Exception as e:
            print(f"Skipping image {i} due to error: {e}")


save_dataset_to_dir(train_data, "/content/dataset/train")
save_dataset_to_dir(valid_data, "/content/dataset/valid")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (224, 224)
batch_size = 32

train_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    "/content/dataset/train",
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

valid_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    "/content/dataset/valid",
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1020 images belonging to 102 classes.
# Found 1020 images belonging to 102 classes.

# %%
# ✅ STEP 4: MOBILENETV2 MODEL
from tensorflow.keras.applications import MobileNetV2

base1 = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
base1.trainable = False

model1 = models.Sequential([
    base1,
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dense(train_gen.num_classes, activation='softmax')
])
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model1.fit(train_gen, validation_data=valid_gen, epochs=3)
model1.save("/content/mobilenet_model.keras")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.0213 - loss: 4.6252 - val_accuracy: 0.0853 - val_loss: 4.2668
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.1465 - loss: 3.9572 - val_accuracy: 0.2480 - val_loss: 3.5514
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.3818 - loss: 3.0075 - val_accuracy: 0.4167 - val_loss: 2.7440

# %%
# 🔽 Quantize MobileNetV2 after training
converter = tf.lite.TFLiteConverter.from_keras_model(model1)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

tflite_mobilenet = converter.convert()

with open("mobilenet_model_fp16.tflite", "wb") as f:
    f.write(tflite_mobilenet)

print("✅ MobileNetV2 TFLite quantized and saved.")
# Out:
# Saved artifact at '/tmp/tmpaaef_my9'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 102), dtype=tf.float32, name=None)
# Captures:
#   136690670605072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670600656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670600464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670222800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670222608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670605840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670604112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670603728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670604496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670607184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670606992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670608720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670605648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670605456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670607760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670610640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670612560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670611216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670611600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670610448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670614096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670613712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670613328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670614288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670612944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670616400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670611792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806145680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670616016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690670615248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806146832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806147216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806147600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806147408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806146064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806148752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806149136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806149520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806149328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806145296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806146448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806151248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806151632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806151440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806147984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806150288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806153360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806153552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806153936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806150672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806152400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806155280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806155664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806155472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806148368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806156816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806157200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806157584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806157392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806153168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806159504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806159312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806154128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806161232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806159888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806161040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806669584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806670928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806671312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806671120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806670544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806672464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806672848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806673232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806673040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806669776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806674384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806674768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806675152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806674960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806669968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690770144400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806670160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806676112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690897682896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806677456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806677840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806678224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806678032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806676304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806679376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806679760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806679952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806672080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806681296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806682064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806681872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806677072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806683216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806683600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806683984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806683792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806678992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806685136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806674000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806685520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806685328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806212176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806211792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806212944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806212752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806210832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806213904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806214480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806214864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806214672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806210640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806215632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806216400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806216784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806216592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806211600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806217552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806218320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806218128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806218512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806213328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806219664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806219856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806220432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806220240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806214288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806221776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806221968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806222544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806222352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806217360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806223504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806224080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806223888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806224272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806219280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806225616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806224848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806226768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806226192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806221392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806224656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771526288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771526864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690806225232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771525904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771528016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771528400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771528784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771525712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771529936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771530320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771530704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771530512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771526480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771531856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771532240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771527632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771534544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771529552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771535696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771536080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771531472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771538000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771538384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771538192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771533392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771539536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771539920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771540304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771535312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771541456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771526096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771541840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771541648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771539152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772035728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772035536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772036880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772037264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772037648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772037456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772038800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772039184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772039568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772039376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772040720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772041104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772041488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772041296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772042640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772043024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772043408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772043216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772038416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772044560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772044944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772045328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772045136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772040336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772046480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772046864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772047248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772047056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772042256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772048400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772048784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772049552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772048976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772044176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772047632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771738704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771739856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690772048016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771739664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771741008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771741392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771741776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771741584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771739472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771742928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771743312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771743696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771743504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771738896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771744848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771745232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771745616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771745424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771740624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771744080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771747920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771747344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771748688: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ MobileNetV2 TFLite quantized and saved.

# %%
# ✅ STEP 5: RESNET50 MODEL
from tensorflow.keras.applications import ResNet50

base2 = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
base2.trainable = False

model2 = models.Sequential([
    base2,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dense(train_gen.num_classes, activation='softmax')
])
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model2.fit(train_gen, validation_data=valid_gen, epochs=3)
model2.save("/content/resnet_model.keras")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 257s 8s/step - accuracy: 0.0112 - loss: 4.7286 - val_accuracy: 0.0098 - val_loss: 4.6212
# Epoch 2/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 262s 8s/step - accuracy: 0.0078 - loss: 4.6207 - val_accuracy: 0.0088 - val_loss: 4.6194
# Epoch 3/3
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 253s 8s/step - accuracy: 0.0116 - loss: 4.6180 - val_accuracy: 0.0108 - val_loss: 4.6234

# %%
# 🔽 Quantize ResNet50 after training
converter = tf.lite.TFLiteConverter.from_keras_model(model2)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

tflite_resnet = converter.convert()

with open("resnet_model_fp16.tflite", "wb") as f:
    f.write(tflite_resnet)

print("✅ ResNet50 TFLite quantized and saved.")
# Out:
# Saved artifact at '/tmp/tmp9vvp_0fi'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_334')
# Output Type:
#   TensorSpec(shape=(None, 102), dtype=tf.float32, name=None)
# Captures:
#   136690771749264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771750608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659394384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659395728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690771750416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659393616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659398800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659399376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659399568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659398416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659394768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659399184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659401104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659401680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659401872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659400720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659395152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659401488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659403408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659403984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659394576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659397072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659397264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659395536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659396880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659404176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659403024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659397648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659403792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659405712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659406288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659406480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659405328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659399952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659406096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659408016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659408592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659409552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659402256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659408400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659407248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690659409168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569069776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569068816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569069584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569068624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569071312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569071888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569072080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569070928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569069008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569073616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569074192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569074384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569073232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569069392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569074000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569075920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569076496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569076688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569075536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569070160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569076304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569080528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569081104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569081296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569080144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569074768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569080912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569082832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569083408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569083600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569082448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569077072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569083216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569082064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569084752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569078224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569078800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569078992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569077840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569072464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569078608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569888784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569888208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569079376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569888400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569890320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569890896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569891088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569889936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569888016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569890704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569892624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569893200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569893392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569892240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569887824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569893008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569894928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569895504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569895696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569894544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569889168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569895312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569897232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569897808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569898000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569896848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569891472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569897616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569899536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569900112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569900304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569899152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569893776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569899920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569901840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569902416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569902608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569901456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569896080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569902224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136693723289296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569903376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569511760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569511376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569898384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569901072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569514064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569512912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569515600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569516176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569516368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569515216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569515984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569520208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569520784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569520976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569519824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569514448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569520592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569522512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569523088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569523280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569522128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569516752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569522896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569524816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569525392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569517904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569518480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569518672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569517520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569518288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569525584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569524432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569519056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569525200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569527120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569526736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568397456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568397072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569525968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690569521360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568398992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568399568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568399760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568398608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568397264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568399376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568401296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568401872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568402064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568400912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568397840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568401680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568403600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568404176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568404368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568403216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568397648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568403984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568405904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568406480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568406672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568405520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568400144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568406288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568408208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568408976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568407824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568402448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568408592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568410512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568411088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568411280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568404752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568410896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568412816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568412432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568134928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568411664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568409360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568136656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568137232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568135888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568137040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568138960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568139536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568138576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568135120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568139344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568141264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568141840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568142032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568140880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568134736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568141648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568143568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568144144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568144336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568143184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568137808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568143952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568145872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568146448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568146640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568148560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568140112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568146256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568149136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568144720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568145104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568149904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568149328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568150288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568150480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568150672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568150864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566938704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568145488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690568148944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566942736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566943312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566943504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566942352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566938896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566943120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566945616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566944656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566939088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566945424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566940432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566941008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566941200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566940048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566939664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566940816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566948112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566941584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566947728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566949648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566950224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566950416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566949264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566943888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566950032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566951952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566951568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566954256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567250384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566953104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690566954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567251536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567252112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567252304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567250192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567250768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567251920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567253840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567254416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567254608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567253456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567251152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567254224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567256144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567256720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567256912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567255760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567250960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567256528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567257680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567259216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567258640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136690567259984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ ResNet50 TFLite quantized and saved.

# %%
# ✅ STEP 6: YOLOv8 CLASSIFIER
from ultralytics import YOLO


model3 = YOLO("yolov8n-cls.pt")
model3.train(data="/content/dataset", epochs=3, imgsz=224)
model3.export(format="onnx")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-cls.pt to 'yolov8n-cls.pt': 100%|██████████| 5.31M/5.31M [00:00<00:00, 43.7MB/s]
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/classify/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/dataset/train... found 1020 images in 102 classes ✅
# val: /content/dataset/valid... found 1020 images in 102 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=102
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    460902  ultralytics.nn.modules.head.Classify         [256, 102]
# YOLOv8n-cls summary: 56 layers, 1,568,950 parameters, 1,568,950 gradients, 3.5 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 605.0±222.1 MB/s, size: 9.7 KB)
# train: Scanning /content/dataset/train... 1020 images, 0 corrupt: 100%|██████████| 1020/1020 [00:00<00:00, 5830.23it/s]
# train: New cache created: /content/dataset/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 475.1±297.6 MB/s, size: 8.6 KB)
# val: Scanning /content/dataset/valid... 1020 images, 0 corrupt: 100%|██████████| 1020/1020 [00:00<00:00, 6076.54it/s]
# val: New cache created: /content/dataset/valid.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=9.4e-05, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to runs/classify/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/3         0G      4.502         16        224:   2%|▏         | 1/64 [00:01<01:03,  1.01s/it]
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100%|██████████| 755k/755k [00:00<00:00, 14.0MB/s]
#         1/3         0G      4.686         12        224: 100%|██████████| 64/64 [00:40<00:00,  1.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 32/32 [00:12<00:00,  2.48it/s]
#                    all     0.0137     0.0667
#
#       Epoch    GPU_mem       loss  Instances       Size
#         2/3         0G      4.593         12        224: 100%|██████████| 64/64 [00:39<00:00,  1.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 32/32 [00:11<00:00,  2.71it/s]
#                    all     0.0235      0.107
#
#       Epoch    GPU_mem       loss  Instances       Size
#         3/3         0G      4.491         12        224: 100%|██████████| 64/64 [00:40<00:00,  1.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 32/32 [00:12<00:00,  2.55it/s]
#                    all     0.0363      0.157
#
# 3 epochs completed in 0.044 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 3.2MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 3.2MB
#
# Validating runs/classify/train/weights/best.pt...
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# YOLOv8n-cls summary (fused): 30 layers, 1,565,542 parameters, 0 gradients, 3.4 GFLOPs
# train: /content/dataset/train... found 1020 images in 102 classes ✅
# val: /content/dataset/valid... found 1020 images in 102 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 32/32 [00:12<00:00,  2.59it/s]
#                    all     0.0363      0.157
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train
# Ultralytics 8.3.173 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# YOLOv8n-cls summary (fused): 30 layers, 1,565,542 parameters, 0 gradients, 3.4 GFLOPs
#
# PyTorch: starting from 'runs/classify/train/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 102) (3.1 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxslim>=0.1.59', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 2.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.62...
# ONNX: export success ✅ 3.5s, saved as 'runs/classify/train/weights/best.onnx' (6.0 MB)
#
# Export complete (3.6s)
# Results saved to /content/runs/classify/train/weights
# Predict:         yolo predict task=classify model=runs/classify/train/weights/best.onnx imgsz=224
# Validate:        yolo val task=classify model=runs/classify/train/weights/best.onnx imgsz=224 data=/content/dataset
# Visualize:       https://netron.app
# 'runs/classify/train/weights/best.onnx'

# %%
# ✅ STEP 7: INFERENCE & TIMING — Example with MobileNetV2
import os
import random


valid_dir = "/content/dataset/valid"
class_dirs = [os.path.join(valid_dir, d) for d in os.listdir(valid_dir) if os.path.isdir(os.path.join(valid_dir, d))]

if class_dirs:

    sample_class_dir = random.choice(class_dirs)

    image_files = [f for f in os.listdir(sample_class_dir) if f.endswith('.jpg')]

    if image_files:

        sample_img_name = random.choice(image_files)
        sample_img_path = os.path.join(sample_class_dir, sample_img_name)
        print(f"Using sample image: {sample_img_path}")

        img = image.load_img(sample_img_path, target_size=img_size)
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0) / 255.0

        model_loaded = tf.keras.models.load_model("/content/mobilenet_model.keras")

        start = time.time()
        pred = model_loaded.predict(x)
        end = time.time()

        print("Predicted class:", np.argmax(pred))
        print("Inference time: {:.2f} ms".format((end - start)*1000))
    else:
        print(f"No image files found in {sample_class_dir}")
else:
    print(f"No class directories found in {valid_dir}")
# Out:
# Using sample image: /content/dataset/valid/3/1002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step
# Predicted class: 25
# Inference time: 1083.31 ms

# %%
# Inference from quantized MobileNetV2 TFLite model
interpreter = tf.lite.Interpreter(model_path="mobilenet_model_fp16.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

img_path = "/content/dataset/valid/3/1002.jpg"
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
input_data = tf.keras.preprocessing.image.img_to_array(img) / 255.0
input_data = np.expand_dims(input_data.astype(np.float32), axis=0)

start = time.time()
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()
output_data = interpreter.get_tensor(output_details[0]['index'])
end = time.time()

print("📦 MobileNetV2 - Predicted class:", np.argmax(output_data))
print("⚡ TFLite inference time: {:.2f} ms".format((end - start) * 1000))
# Out:
# 📦 MobileNetV2 - Predicted class: 25
# ⚡ TFLite inference time: 11.43 ms

# %%
# Inference from quantized ResNet50 TFLite model
interpreter = tf.lite.Interpreter(model_path="resnet_model_fp16.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

img_path = "/content/dataset/valid/3/1002.jpg"
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
input_data = tf.keras.preprocessing.image.img_to_array(img) / 255.0
input_data = np.expand_dims(input_data.astype(np.float32), axis=0)

start = time.time()
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()
output_data = interpreter.get_tensor(output_details[0]['index'])
end = time.time()

print("📦 ResNet50 - Predicted class:", np.argmax(output_data))
print("⚡ TFLite inference time: {:.2f} ms".format((end - start) * 1000))
# Out:
# 📦 ResNet50 - Predicted class: 70
# ⚡ TFLite inference time: 101.88 ms

# %%
import cv2
import onnxruntime as ort


session = ort.InferenceSession("/content/runs/classify/train/weights/best.onnx")
input_name = session.get_inputs()[0].name

img_cv = cv2.imread(sample_img_path)
img_cv = cv2.resize(img_cv, (224, 224)).astype(np.float32) / 255.0
img_cv = np.transpose(img_cv, (2, 0, 1))
img_cv = np.expand_dims(img_cv, axis=0)

start = time.time()
output = session.run(None, {input_name: img_cv})[0]
end = time.time()

print("YOLOv8 Class:", np.argmax(output))
print("YOLOv8 Inference Time: {:.2f} ms".format((end - start)*1000))
# Out:
# YOLOv8 Class: 33
# YOLOv8 Inference Time: 8.13 ms

# %%
import cv2
import onnxruntime as ort

# Inference from YOLOv8 ONNX classification model
onnx_model_path = "runs/classify/train/weights/best.onnx"

session = ort.InferenceSession(onnx_model_path)
input_name = session.get_inputs()[0].name

img_path = "/content/dataset/valid/3/1002.jpg"
img = cv2.imread(img_path)
img = cv2.resize(img, (224, 224))
img = img.astype(np.float32) / 255.0
img = np.transpose(img, (2, 0, 1))
img = np.expand_dims(img, axis=0)

start = time.time()
output = session.run(None, {input_name: img})[0]
end = time.time()

print("📦 YOLOv8 - Predicted class:", np.argmax(output))
print("⚡ ONNX inference time: {:.2f} ms".format((end - start) * 1000))
# Out:
# 📦 YOLOv8 - Predicted class: 33
# ⚡ ONNX inference time: 9.23 ms

# %% [markdown]
# # ✅ Task 1 Completed
#
# We successfully:
# - Trained 3 image classification models
# - Quantized MobileNetV2 and ResNet50 using TFLite
# - Exported YOLOv8 to ONNX format
# - Achieved < 20ms inference time on YOLOv8 and MobileNetV2
#
# All models were tested on the Oxford Flowers 102 dataset.
